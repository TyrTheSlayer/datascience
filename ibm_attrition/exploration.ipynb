# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
ibm = pd.read_csv("~/datascience/ibm_attrition/IBM.csv")

# %%
ibm.head()
# Out:
#    Age Attrition              Department  DistanceFromHome  Education  \
# 0   41       Yes                   Sales                 1          2
# 1   49        No  Research & Development                 8          1
# 2   37       Yes  Research & Development                 2          2
# 3   33        No  Research & Development                 3          4
# 4   27        No  Research & Development                 2          1
#
#   EducationField  EnvironmentSatisfaction  JobSatisfaction MaritalStatus  \
# 0  Life Sciences                        2                4        Single
# 1  Life Sciences                        3                2       Married
# 2          Other                        4                3        Single
# 3  Life Sciences                        4                3       Married
# 4        Medical                        1                2       Married
#
#    MonthlyIncome  NumCompaniesWorked  WorkLifeBalance  YearsAtCompany
# ...

# %% [markdown]
# Plotting to see relationships between metrics

# %%
plt.figure(figsize=(14, 5))
sns.set_palette("muted")
sns.scatterplot(data=ibm, x="Age", y="MonthlyIncome", hue="Attrition")
plt.title("Age versus Monthly Income")
plt.xlabel("Age (Years)")
plt.ylabel("Monthly Income (USD)")
# Out:
# Text(0, 0.5, 'Monthly Income (USD)')
